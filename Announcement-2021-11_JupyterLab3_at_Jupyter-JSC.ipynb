# %% [markdown]
# ![jsc-logo.jpg](attachment:67258d94-84e6-4a0c-ae8f-c74332ec082e.jpg)
# Author: [Jens Henrik Göbbert](mailto:j.goebbert@fz-juelich.de)
# ------------------------------------

# %% [markdown]
# # Welcome JupyterLab 3.2 on Jupyter-JSC
#
# **JupyterLab** is continuously evolving and the current version 3.2 brings a lot of new fantastic functionalities and possibilities.
# All the more we are happy to announce that we can now provide you with JupyterLab 3 as an access point to our systems via Jupyter-JSC on https://jupyter-jsc.fz-juelich.de.
#
# **Jupyter-JSC** saw the light of day four years ago and continues to grow at JSC with new functions and tasks. Its main purpose is to enable interactive supercomputing via JupyterLab at Jülich Supercomputing Centre.
# It is part of the Helmholtz Cloud (https://cloud.helmholtz.de) and makes it possible to use the HPC systems of the JSC and also the HDF Cloud in everyday work completely from within the web browser.
# Today, about 500 JupyterLab sessions are started by about 100 different users via Jupyter-JSC per week.
#
# To help you get the most out of the JupyterLab 3 setup, here are the _Highlights_, _Interface Changes_ and _Extensions_:
#
# -------------------------

# %% [markdown]
# ## Highlights

# %% [markdown]
# ### Debugger
# JupyterLab 3 comes with a front-end debugger by default. This means that notebooks, code consoles, and files can now be debugged from JupyterLab directly.
# This is possible, if the kernel supports the [Jupyter Debugger Protocol](https://jupyter-client.readthedocs.io/en/latest/messaging.html#debug-request) which is for the start true for the default Python kernel driven by [IPython](https://ipython.readthedocs.io/en/stable/) in the included version 6+.
# <img src="attachment:9390596b-a5ba-4fdb-94b4-88995bc1e539.png" width="500"/>
#
# (more details [HERE](https://blog.jupyter.org/a-visual-debugger-for-jupyter-914e61716559) and [HERE](https://jupyterlab.readthedocs.io/en/stable/user/debugger.html) )

# %% [markdown]
# ### Prebuild Extensions
# The software architecture of JupyterLab has always allowed extensions to customize/improve any part of JupyterLab. However, installing an extension required rebuilding the whole JupyterLab. Thus, due to the system-wide installation, the choice of extensions under Jupyter-JSC was hard-wired to the JupyterLab installation in the past.
#
# JupyterLab 3 now supports so-called _prebuild extensions_ in addition to the classical _source extensions_.
# They are installed independently from the JupyterLab installation like any other Python package and do not require a rebuild of the underlying JupyterLab.
#
# _Prebuild extensions_ thus bring great advantages as ...
# - ... there is **no need to rebuild** JupyterLab to install new _prebuild extensions_.
# - ... the choice of activated _prebuild extensions_ is **made at startup** of JupyterLab, not at build time.
# - ... a system-wide JupyterLab installation can be technically **extended users/projects** with additional _prebuild extensions_.
# - ... updates of _prebuild extensions_ can be done separately from the JupyterLab installation with much **smaller risk** to break the JupyterLab installation.
# - ... competing dependencies of different extensions are **better shielded** from each other.
#
# (more details [HERE](https://jupyterlab.readthedocs.io/en/stable/extension/extension_dev.html#prebuilt-extensions) and [HERE](https://github.com/jupyterlab/extension-examples))
#
# **Example:**
# Currently we use the new possibility of _prebuild extensions_ to load the extension [NVDashboard](https://github.com/rapidsai/jupyterlab-nvdashboard) when JupyterLab starts on a system with GPUs.
# <img src="attachment:a3490a16-d833-4e62-afdc-50351d71a259.png" width="500"/>
#
# (more details [HERE](https://developer.nvidia.com/blog/gpu-dashboards-in-jupyter-lab/) )

# %% [markdown]
# ### Collaborative editing — à la Google Docs
#
# **NOTE:** At the moment this feature is **NOT** supported within Jupyter-JSC as it is forbidden to share user accounts.
#
# Multiple attempts have been made to introduce collaborative editing in JupyterLabs - finally it came in JupyterLab 3.1 to stay!
# Now, file documents and notebooks have the possibility for collaborative editing using the [Yjs shared editing framework](https://github.com/yjs/yjs).
# Yjs is network agnostic (p2p!) and there has no need for a central management server and still allows features like offline editing and undo/redo for a shared document.
# <img src="attachment:0e0ba029-7c50-41f8-bbf3-8e21bcdd8539.gif" width="500"/>
#
# (more details [HERE](https://blog.jupyter.org/how-we-made-jupyter-notebooks-collaborative-with-yjs-b8dff6a9d8af) and [HERE](https://jupyterlab.readthedocs.io/en/stable/user/rtc.html) )

# %% [markdown]
# ## Changes in the Interface

# %% [markdown]
# - A new **visual indicator** was introduced to highlight cells in which the code changed in the editor since last execution
#
#   <img src="attachment:37fad88b-31e7-4347-9746-ea5013761b12.png" width="300"/>
#   <img src="attachment:43941632-d3b5-466b-8208-f1892409c134.png" width="300"/>

# %% [markdown]
# - Add a menu entry to **show/hide hidden files** in the filebrowser
#
#   <img src="attachment:4c8d3105-4dfe-4d5a-bbf4-68d54a563286.png" width="500"/>

# %% [markdown]
# - The file browser now has a **filter input** which filters the list of files using the same fuzzy matching as the command palette.
#
#   <img src="attachment:a9a4a1b2-9a2c-44a1-9be9-ac3234cfa0dc.png" width="500"/>

# %% [markdown]
# - The **Table of Content** extension got integrated into JupyterLab 3. Now you can easily see and navigate through the structure of your document.
#
#   <img src="attachment:0537dd88-829f-460c-8ac0-89ecdcbcb41a.gif" width="500"/>

# %% [markdown]
# - The **property inspector** moved to the right sidebar.
#
#   <img src="attachment:94a349b2-a0f4-4955-a79c-23edcf0cd888.png" width="500"/>

# %% [markdown]
# - The **command palette** now comes floating on the center of the top of the window. This enables users to quickly invoke a command while keeping the sidebar closed or switching sidebar panels.
# You can access the command palette using the View menu or directly using the shortcut **Ctrl+Shift+C**.
#
#   <img src="attachment:73e57835-8df8-4b4b-ac5f-307d2375f546.png" width="500"/>

# %% [markdown]
# - And if we talk about **Simple Interface mode** then it has been extensively updated for a more targeted, documented-oriented feel.
# There is a toggle on the command prompt to switch to the Simple Interface mode,
#
#   <img src="attachment:375474eb-0a48-449c-8b36-26c1843c836e.png" width="500"/>

# %% [markdown]
# - **Side-by-side rendering** was added in JupyterLab 3
#
#   <img src="attachment:c6917772-ede3-43ab-9fa5-aaff7d7ac209.png" width="500"/>

# %% [markdown]
# - Show **trailing white spaces**
#
#   <img src="attachment:2ff5bee0-dc3f-496f-aa50-78b32f970032.png" width="300"/>

# %% [markdown]
# - The undo/redo history in the notebook is now document-wide (tracking changes across all cells)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Complete Changelog:</b>
# Of course there are far more changes. Just have a look at the complete changelog
# <a href="https://jupyterlab.readthedocs.io/en/stable/getting_started/changelog.html">[HERE]</a>
# </div>
#
# ------------------------------------------------------------

# %% [markdown]
# ## Extensions

# %% [markdown]
# ### Highlights

# %% [markdown]
# - [@jupyterlab/server-proxy](https://github.com/jupyterhub/jupyter-server-proxy)
# Jupyter Server Proxy lets you run arbitrary external processes (such as our remote desktop over Xpra, etc) alongside your notebook server and provide authenticated web access to them.
#
#   <img src="attachment:7f85f173-0b85-4591-94bc-01213d29ca56.png" width="300"/>

# %% [markdown]
# - [jupyterlab-system-monitor](https://github.com/jtpio/jupyterlab-system-monitor)
# JupyterLab extension to display system information (memory and cpu usage).
#
#   <img src="attachment:205d8962-61a8-4848-bf37-6da0b905114f.png" width="300"/>

# %% [markdown]
# - [@jupyterlab/git](https://github.com/jupyterlab/jupyterlab-git)
# A JupyterLab extension for version control using Git
#
#   <img src="attachment:163010e3-3ac6-44c4-b5d3-12bca422e148.png" width="300"/>

# %% [markdown]
# - [@krassowski/jupyterlab-lsp](https://github.com/jupyter-lsp/jupyterlab-lsp)
# JupyterLab-LSP is the Language Server Protocol integration for Jupyter(Lab).
# On Jupyter-JSC we installed language server for
# [Python](https://github.com/microsoft/pyright),
# [Bash](https://github.com/bash-lsp/bash-language-server),
# [JavaScript/TypeScript](https://github.com/sourcegraph/javascript-typescript-langserver),
# [SQL](https://github.com/joe-re/sql-language-server),
# [CSS](https://github.com/vscode-langservers/vscode-css-languageserver-bin),
# [JSON](https://github.com/vscode-langservers/vscode-json-languageserver-bin),
# [HTML](https://github.com/vscode-langservers/vscode-html-languageserver-bin),
# [YAML](https://github.com/redhat-developer/yaml-language-server),
# [Dockerfile](https://github.com/rcjsuen/dockerfile-language-server-nodejs)
# The Jupyter Kernel for Julia and R are coming with language server as well.
#   - [Hover](https://github.com/jupyter-lsp/jupyterlab-lsp#hover)
#
#     <img src="attachment:36f7b961-36d0-45a6-9201-a87834e3e46d.png" width="300"/>
#
#   - [Diagnostics](https://github.com/jupyter-lsp/jupyterlab-lsp#diagnostics)
#
#     <img src="attachment:3ed54e81-dd14-4eb6-b333-b613a500691f.png" width="300"/>
#
#   - [Jump to Definition](https://github.com/jupyter-lsp/jupyterlab-lsp#jump-to-definition)
#
#     <img src="attachment:66beb3e7-0bef-4ff3-a195-873e465d1566.png" width="300"/>
#
#   - [Automatic Completion and Continuous Hinting](https://github.com/jupyter-lsp/jupyterlab-lsp#automatic-completion-and-continuous-hinting)
#
#     <img src="attachment:6c0b962b-f3bc-4973-9b8b-ef1075bcb344.gif" width="400"/>
#
#   - [Automatic Signature Suggestions](https://github.com/jupyter-lsp/jupyterlab-lsp#automatic-signature-suggestions)
#
#     <img src="attachment:bc383288-fbaa-4dc7-b56d-62155654fac3.png" width="300"/>
#
#   - [Kernel-less Autocompletion](https://github.com/jupyter-lsp/jupyterlab-lsp#kernel-less-autocompletion)
#
#     <img src="attachment:2bdcc9bf-4d9d-4285-91e5-74de7dd5e2b8.gif" width="300"/>

# %% [markdown]
# - [jupyterlab-nvdashboard](https://github.com/rapidsai/jupyterlab-nvdashboard)
# NVDashboard is an open-source package for the real-time visualization of NVIDIA GPU metrics in interactive Jupyter Lab environments.
#
#   <img src="attachment:a303c9a6-12e5-40eb-b900-bd563c929aad.png" width="500"/>
#
# (more details [HERE](https://developer.nvidia.com/blog/gpu-dashboards-in-jupyter-lab/) )

# %% [markdown]
# ### Detailed List
#
# Extensions known from our JupyterLab 2 installation on Jupyter-JSC
# and **updated or new**:
#
# | Extensions                  | old version    | new version    | type     |
# | :---                        |    :----:      | :---:          | ---:     |
# | **Core** ||||
# | [@jupyterlab/server-proxy](https://github.com/jupyterhub/jupyter-server-proxy)                             | v2.1.0         | v3.1.0         | prebuild       |
# | [@jupyter-widgets/jupyterlab-manager](https://github.com/jupyter-widgets/ipywidgets)                       | v2.0.0         | v3.0.1         | prebuild       |
# | [jupyterlab-datawidgets](https://github.com/vidartf/ipydatawidgets)                                        | v6.3.0         | v7.0.0         | source         |
# | **UI Enhancements** ||||
# | [@jlab-enhanced/recents](https://github.com/jupyterlab-contrib/jupyterlab-recents)                         |                | v3.0.1         | prebuild       |
# | [@jlab-enhanced/favorites](https://github.com/jupyterlab-contrib/jupyterlab-favorites)                     | v2.0.0         | v3.0.0         | prebuild       |
# | [jupyterlab-topbar-extension](https://github.com/jupyterlab-contrib/jupyterlab-topbar)                     | v0.5.0         | v0.6.1         |                |
# | [jupyterlab-system-monitor](https://github.com/jtpio/jupyterlab-system-monitor)                            | v0.6.0         | v0.8.0         | prebuild       |
# | [@jupyter-server/resource-usage](https://github.com/jupyter-server/jupyter-resource-usage)                 |                | v0.6.0         | n/a            |
# | [jupyterlab-theme-toggle](https://github.com/jtpio/jupyterlab-theme-toggle)                                | v0.5.0         | v0.6.1         | source         |
# | [jupyterlab-controlbtn](https://github.com/jhgoebbert/jupyterlab-controlbtn)                               | [jupyterlab-control](https://github.com/kreuzert/jupyterlab-control) | v0.5.0         | n/a |
# | [@jupyterlab/toc](https://github.com/jupyterlab/jupyterlab-toc)                                            | v4.0.0         | integrated into JupyterLab 3 ||
# | **Developer Tools** |||
# | [@jupyterlab/git](https://github.com/jupyterlab/jupyterlab-git)                                            | v0.23.3        | v0.32.4        | prebuild       |
# | [jupyterlab-gitlab](https://gitlab.com/beenje/jupyterlab-gitlab)                                           | v2.0.0         | v3.0.0         | prebuild       |
# | [@krassowski/jupyterlab-lsp](https://github.com/jupyter-lsp/jupyterlab-lsp)                                | v2.1.3         | v3.9.0         | prebuild       |
# | [nbdime-jupyterlab](https://github.com/jupyter/nbdime)                                                     | v2.1.0         | v3.1.0         | prebuild       |
# | [@ryantam626/jupyterlab_code_formatter](https://github.com/ryantam626/jupyterlab_code_formatter)           | v1.3.8         | v1.4.10        | prebuild       |
# | [@ijmbarr/jupyterlab_spellchecker](https://github.com/jupyterlab-contrib/spellchecker)                     | v0.2.0         | v0.7.2         | prebuild       |
# | [jupyterlab-nvdashboard](https://github.com/rapidsai/jupyterlab-nvdashboard)                               |                | v0.6.0         | prebuild       |
# | **Data Visualization** |||
# | [jupyter-matplotlib](https://github.com/matplotlib/ipympl)                                                 | v0.7.4         | v0.9.0         | prebuild       |
# | [@bokeh/jupyter_bokeh](https://github.com/bokeh/jupyter_bokeh)                                             | v2.0.4         | v3.0.4         | prebuild       |
# | [jupyterlab-plotly](https://github.com/plotly/plotly.py/tree/master/packages/javascript/jupyterlab-plotly) | v4.14.3        | v5.3.1         ||
# | [bqplot](https://github.com/bqplot/bqplot)                                                                 | v0.5.22        | v0.5.32        | prebuild       |
# | [@pyviz/jupyterlab_pyviz](https://github.com/holoviz/pyviz_comms)                                          | v1.0.4         | v2.1.0         | prebuild       |
# | [jupyter-leaflet](https://github.com/jupyter-widgets/ipyleaflet)                                           | v0.13.3        | v0.14.0        | prebuild       |
# | [ipyvolume](https://github.com/maartenbreddels/ipyvolume)                                                  | v0.6.0-alpha.5 | v0.6.0-alpha.8 | prebuild       |
# | [jupyter-threejs](https://github.com/jupyter-widgets/pythreejs)                                            | v2.2.0         | v2.3.0         | prebuild       |
# | [@jupyter-widgets/jupyterlab-sidecar](https://github.com/jupyter-widgets/jupyterlab-sidecar)               | v0.5.0         | v0.6.1         | prebuild       |
# | **Framework Integrations** |||
# | [dask-labextension](https://github.com/dask/dask-labextension)                                             | v3.0.0         | v5.1.0         | prebuild       |
# | [@jupyterlab/latex](https://github.com/jupyterlab/jupyterlab-latex)                                        | v2.0.1         | v3.1.0         | prebuild       |
# | [jupyter-webrtc](https://github.com/maartenbreddels/ipywebrtc)                                             | v0.5.0         | v0.6.0         | prebuild       |
# | **Dashboard Developement** |||
# | [jupyter-vue](https://github.com/mariobuikhuizen/ipyvue)                                                   | v1.5.0         | v1.6.1         ||
# | [jupyter-vuetify](https://github.com/mariobuikhuizen/ipyvuetify)                                           | v1.6.1         | v1.8.1         ||
# | [@voila-dashboards/jupyterlab-preview](https://github.com/voila-dashboards/voila)                          | v1.1.0         | v2.1.0-alpha.2 | prebuild       |
# | [jupyterlab-dash](https://github.com/plotly/jupyter-dash)                                                  | v0.4.0         | v0.4.0         | prebuild       |
# | **Welcome** |||
# | [jupyterlab_iframe](https://github.com/timkpaine/jupyterlab_iframe)                                        | v0.3.0         | v0.4.0         | source         |
# | [jupyterlab-tour](https://github.com/jupyterlab-contrib/jupyterlab-tour)                                   |                | v3.1.3         | prebuild       |
#
# Extensions known from our JupyterLab 2 installation on Jupyter-JSC,
# but in the current version **not compatible** with our new JupyterLab 3 installation:
#
# | Extensions                  | old version    | new version    |
# | :---                        |    :----:      | :---:          |
# | [itkwidgets](https://github.com/InsightSoftwareConsortium/itkwidgets)                                      | v0.32.0        |  [upcoming](https://github.com/InsightSoftwareConsortium/itkwidgets/issues/405) |
# | [jsfileupload](https://gitlab.jsc.fz-juelich.de/jupyter4jsc/j4j_extras/jsfileupload)                       | v0.2.0         |                |
# | [dicom-upload](https://gitlab.jsc.fz-juelich.de/jupyter4jsc/j4j_extras/dicom-upload)                       | v0.2.0         |                |
# | [pvlink](https://gitlab.jsc.fz-juelich.de/jupyter4jsc/j4j_extras/pvlink)                                   | v0.3.1         |                |
#
# Extensions known from our JupyterLab 2 installation on Jupyter-JSC,
# but **decided to remove** in our new JupyterLab 3 installation:
#
# | Extensions                  | old version    | new version    |
# | :---                        |    :----:      | :---:          |
# | [jupyter-lmod](https://github.com/cmd-ntrf/jupyter-lmod)                                                   | v2.0.2         |                |
# | [@parente/jupyterlab-quickopen](https://github.com/parente/jupyterlab-quickopen)                           | v0.5.0         |                |
# | [@krassowski/jupyterlab_go_to_definition]()                                                                | v1.0.0         | now in [@krassowski/jupyterlab-lsp](https://github.com/jupyter-lsp/jupyterlab-lsp) |
# | [plotlywidget](https://github.com/plotly/plotly.py)                                                        | v4.14.3        | now [jupyterlab-plotly](https://github.com/plotly/plotly.py/tree/master/packages/javascript/jupyterlab-plotly) |

# %% [markdown]
# ## FAQs:
# - JupyterLab 3.0 got released as Christmas present last year. Why did you update to JupyterLab 3 this late?
#     - Many third-party extensions were still in the process of updating to be compatible with JupyterLab 3 over the last year.
#     - Until summer the JupyterLab debugging feature required the special XPython kernel and was not supported by the standard IPython kernel, yet.
#     - Minor additions like the feature for showing hidden files in the file-browser was worth waiting for.
#     - And of course: JupyterLab 3 has gained a lot of functionality and stability this year.
